# %%
import numpy as np
import ctypes
import time
import os
import sys
import copy
import matplotlib.pyplot as plt
import logging

_import_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
if _import_path not in sys.path:
    sys.path.insert(0, _import_path)

# hardware
import pyvisa
import hardware.afg3000 as tek
import hardware.hameg as ha
#import hardware.sr_lockin as lo
import hardware.Motordriver as mo

from nidaq_device_modTR import NidaqDevice
from configuration_parser import load_config, ConfigIntegrityException
from measurement_worker import MeasurementWorker

# %%
log_formatter = logging.Formatter("%(asctime)s [%(levelname)s]  %(message)s")
logger = logging.getLogger('measurement_logger')

handlers_registered = False
if not handlers_registered:
    handlers_registered = True
    
    file_handler = logging.FileHandler(os.path.join(os.getcwd(), 'log.log'))
    file_handler.setFormatter(log_formatter)
    logger.addHandler(file_handler)

    console_handler = logging.StreamHandler()
    console_handler.setFormatter(log_formatter)
    logger.addHandler(console_handler)

logger.setLevel(logging.INFO)
logger.propagate = False

# %%
configure_folder_path = os.path.join(os.getcwd(), 'configs')
configure_filenames = os.listdir(configure_folder_path)

for config_filename in configure_filenames:
    config_filepath = os.path.join(configure_folder_path, config_filename)
    try:
        logger.info('Read config file: {}'.format(config_filepath))
        cfg = load_config(config_filepath)
    except ConfigIntegrityException:
        # TODO: add logfile
        exc_info = sys.exc_info()
        raise exc_info[0], exc_info[1], exc_info[2]
    
    try:
        hameg = ha.HMP2030(device="hameg01", voltage_max=20., current_max=0.07)
        tektronix = tek.AFG3252("TCPIP0::129.69.46.235::inst0::INSTR")
        #lock_in = lo.SR830("GPIB0::08::INSTR")
        motor = mo.Motordriver('COM4')

        use_lock_in = cfg['outputs']['lock_in']['active']
        nidaq_config = cfg['devices']['nidaq']
        nidaq = NidaqDevice()
        nidaq.load_config(nidaq_config, use_lock_in=use_lock_in)
        mw = MeasurementWorker(nidaq=nidaq, tektronix=tektronix, hameg=hameg, lock_in=None, motor=motor, logger=logger)
        mw.set_config(cfg) # load measurement config
        mw.set_base_path(os.path.join('n:', os.sep, 'data', '2016', 'magnetometer'))

        mw.measure(save=True, config_path=config_filepath)

    except Exception, e:
    
        # TODO: add logfile
        exc_info = sys.exc_info()
        raise exc_info[0], exc_info[1], exc_info[2]
    finally:
        hameg.close()
    try:
        motor.disconnect()
    except SerialException:
        pass
# Out:
# 2016-04-11 19:13:08,532 [INFO]  Read config file: N:\software\meassrc\magnetometer\new_meas03\configs\config-10.yaml
# Exception serial.serialutil.SerialException: SerialException('Attempting to use a port that is not open',) in <bound method Motordriver.__del__ of <hardware.Motordriver.Motordriver instance at 0x000000000C4B7488>> ignored
# 2016-04-11 19:13:10,269 [INFO]  R2: set offset to 0.0. dev: hameg, ch: 1
# 2016-04-11 19:13:14,371 [INFO]  R2: set offset to 0.01. dev: hameg, ch: 1
# 2016-04-11 19:13:18,464 [INFO]  R2: set offset to 0.02. dev: hameg, ch: 1
# 2016-04-11 19:13:22,565 [INFO]  R2: set offset to 0.03. dev: hameg, ch: 1
# 2016-04-11 19:13:26,667 [INFO]  R2: set offset to 0.04. dev: hameg, ch: 1
# 2016-04-11 19:13:30,769 [INFO]  R2: set offset to 0.05. dev: hameg, ch: 1
# 2016-04-11 19:13:34,871 [INFO]  R2: set offset to 0.06. dev: hameg, ch: 1
# 2016-04-11 19:13:38,970 [INFO]  R2: set offset to 0.07. dev: hameg, ch: 1
# 2016-04-11 19:13:43,072 [INFO]  R2: set offset to 0.08. dev: hameg, ch: 1
# 2016-04-11 19:13:47,173 [INFO]  R2: set offset to 0.09. dev: hameg, ch: 1
# 2016-04-11 19:13:51,270 [INFO]  R2: set offset to 0.1. dev: hameg, ch: 1
# 2016-04-11 19:13:55,372 [INFO]  R2: set offset to 0.11. dev: hameg, ch: 1
# 2016-04-11 19:13:59,474 [INFO]  R2: set offset to 0.12. dev: hameg, ch: 1
# 2016-04-11 19:14:03,576 [INFO]  R2: set offset to 0.13. dev: hameg, ch: 1
# 2016-04-11 19:14:07,681 [INFO]  R2: set offset to 0.14. dev: hameg, ch: 1
# 2016-04-11 19:14:11,789 [INFO]  R2: set offset to 0.15. dev: hameg, ch: 1
# 2016-04-11 19:14:15,891 [INFO]  R2: set offset to 0.16. dev: hameg, ch: 1
# 2016-04-11 19:14:19,989 [INFO]  R2: set offset to 0.17. dev: hameg, ch: 1
# 2016-04-11 19:14:24,091 [INFO]  R2: set offset to 0.18. dev: hameg, ch: 1
# 2016-04-11 19:14:28,194 [INFO]  R2: set offset to 0.19. dev: hameg, ch: 1
# 2016-04-11 19:14:32,299 [INFO]  R2: set offset to 0.2. dev: hameg, ch: 1
# 2016-04-11 19:14:36,405 [INFO]  R2: set offset to 0.21. dev: hameg, ch: 1
# 2016-04-11 19:14:40,507 [INFO]  R2: set offset to 0.22. dev: hameg, ch: 1
# 2016-04-11 19:14:44,611 [INFO]  R2: set offset to 0.23. dev: hameg, ch: 1
# 2016-04-11 19:14:48,713 [INFO]  R2: set offset to 0.24. dev: hameg, ch: 1
# 2016-04-11 19:14:52,816 [INFO]  R2: set offset to 0.25. dev: hameg, ch: 1
# 2016-04-11 19:14:56,920 [INFO]  R2: set offset to 0.26. dev: hameg, ch: 1
# 2016-04-11 19:15:01,019 [INFO]  R2: set offset to 0.27. dev: hameg, ch: 1
# 2016-04-11 19:15:05,118 [INFO]  R2: set offset to 0.28. dev: hameg, ch: 1
# 2016-04-11 19:15:09,226 [INFO]  R2: set offset to 0.29. dev: hameg, ch: 1
# 2016-04-11 19:15:13,322 [INFO]  R2: set offset to 0.3. dev: hameg, ch: 1
# 2016-04-11 19:15:17,424 [INFO]  R2: set offset to 0.31. dev: hameg, ch: 1
# 2016-04-11 19:15:21,523 [INFO]  R2: set offset to 0.32. dev: hameg, ch: 1
# 2016-04-11 19:15:25,625 [INFO]  R2: set offset to 0.33. dev: hameg, ch: 1
# 2016-04-11 19:15:29,727 [INFO]  R2: set offset to 0.34. dev: hameg, ch: 1
# 2016-04-11 19:15:33,829 [INFO]  R2: set offset to 0.35. dev: hameg, ch: 1
# 2016-04-11 19:15:37,933 [INFO]  R2: set offset to 0.36. dev: hameg, ch: 1
# 2016-04-11 19:15:42,029 [INFO]  R2: set offset to 0.37. dev: hameg, ch: 1
# 2016-04-11 19:15:46,131 [INFO]  R2: set offset to 0.38. dev: hameg, ch: 1
# 2016-04-11 19:15:50,233 [INFO]  R2: set offset to 0.39. dev: hameg, ch: 1
# 2016-04-11 19:15:54,336 [INFO]  R2: set offset to 0.4. dev: hameg, ch: 1
# 2016-04-11 19:15:58,434 [INFO]  R2: set offset to 0.41. dev: hameg, ch: 1
# 2016-04-11 19:16:02,529 [INFO]  R2: set offset to 0.42. dev: hameg, ch: 1
# 2016-04-11 19:16:06,632 [INFO]  R2: set offset to 0.43. dev: hameg, ch: 1
# 2016-04-11 19:16:10,727 [INFO]  R2: set offset to 0.44. dev: hameg, ch: 1
# 2016-04-11 19:16:14,828 [INFO]  R2: set offset to 0.45. dev: hameg, ch: 1
# 2016-04-11 19:16:18,928 [INFO]  R2: set offset to 0.46. dev: hameg, ch: 1
# 2016-04-11 19:16:23,029 [INFO]  R2: set offset to 0.47. dev: hameg, ch: 1
# 2016-04-11 19:16:27,131 [INFO]  R2: set offset to 0.48. dev: hameg, ch: 1
# 2016-04-11 19:16:31,234 [INFO]  R2: set offset to 0.49. dev: hameg, ch: 1
# 2016-04-11 19:16:35,339 [INFO]  R2: set offset to 0.5. dev: hameg, ch: 1
# 2016-04-11 19:16:39,443 [INFO]  R2: set offset to 0.51. dev: hameg, ch: 1
# 2016-04-11 19:16:43,543 [INFO]  R2: set offset to 0.52. dev: hameg, ch: 1
# 2016-04-11 19:16:47,644 [INFO]  R2: set offset to 0.53. dev: hameg, ch: 1
# 2016-04-11 19:16:51,742 [INFO]  R2: set offset to 0.54. dev: hameg, ch: 1
# 2016-04-11 19:16:55,841 [INFO]  R2: set offset to 0.55. dev: hameg, ch: 1
# 2016-04-11 19:16:59,937 [INFO]  R2: set offset to 0.56. dev: hameg, ch: 1
# 2016-04-11 19:17:04,035 [INFO]  R2: set offset to 0.57. dev: hameg, ch: 1
# 2016-04-11 19:17:08,134 [INFO]  R2: set offset to 0.58. dev: hameg, ch: 1
# 2016-04-11 19:17:12,236 [INFO]  R2: set offset to 0.59. dev: hameg, ch: 1
# 2016-04-11 19:17:16,339 [INFO]  R2: set offset to 0.6. dev: hameg, ch: 1
# 2016-04-11 19:17:20,433 [INFO]  R2: set offset to 0.61. dev: hameg, ch: 1
# 2016-04-11 19:17:24,528 [INFO]  R2: set offset to 0.62. dev: hameg, ch: 1
# 2016-04-11 19:17:28,628 [INFO]  R2: set offset to 0.63. dev: hameg, ch: 1
# 2016-04-11 19:17:32,730 [INFO]  R2: set offset to 0.64. dev: hameg, ch: 1
# 2016-04-11 19:17:36,832 [INFO]  R2: set offset to 0.65. dev: hameg, ch: 1
# 2016-04-11 19:17:40,936 [INFO]  R2: set offset to 0.66. dev: hameg, ch: 1
# 2016-04-11 19:17:45,036 [INFO]  R2: set offset to 0.67. dev: hameg, ch: 1
# 2016-04-11 19:17:49,141 [INFO]  R2: set offset to 0.68. dev: hameg, ch: 1
# 2016-04-11 19:17:53,242 [INFO]  R2: set offset to 0.69. dev: hameg, ch: 1
# 2016-04-11 19:17:57,342 [INFO]  R2: set offset to 0.7. dev: hameg, ch: 1
# 2016-04-11 19:18:01,443 [INFO]  R2: set offset to 0.71. dev: hameg, ch: 1
# 2016-04-11 19:18:05,542 [INFO]  R2: set offset to 0.72. dev: hameg, ch: 1
# 2016-04-11 19:18:09,644 [INFO]  R2: set offset to 0.73. dev: hameg, ch: 1
# 2016-04-11 19:18:13,746 [INFO]  R2: set offset to 0.74. dev: hameg, ch: 1
# 2016-04-11 19:18:17,849 [INFO]  R2: set offset to 0.75. dev: hameg, ch: 1
# 2016-04-11 19:18:21,953 [INFO]  R2: set offset to 0.76. dev: hameg, ch: 1
# 2016-04-11 19:18:26,051 [INFO]  R2: set offset to 0.77. dev: hameg, ch: 1
# 2016-04-11 19:18:30,144 [INFO]  R2: set offset to 0.78. dev: hameg, ch: 1
# 2016-04-11 19:18:34,232 [INFO]  R2: set offset to 0.79. dev: hameg, ch: 1
# 2016-04-11 19:18:38,325 [INFO]  R2: set offset to 0.8. dev: hameg, ch: 1

# %%
motor.disconnect()

# %%
import copy
a = ['a1', 'a2', 'a3']
b = ['b1', 'b2', 'b3']
c = ['c1', 'c2', 'c3']
x = [a, b, c]

def rec(x, level=0):
    if len(x) == 0:
        return
    xnew = copy.copy(x)
    r = xnew.pop()
    for i in r:
        print str(i) + ' level=' + str(level)
        rec(xnew, level=level+1)
        
x.reverse()
rec(x)
# Out:
# a1 level=0
# b1 level=1
# c1 level=2
# c2 level=2
# c3 level=2
# b2 level=1
# c1 level=2
# c2 level=2
# c3 level=2
# b3 level=1
# c1 level=2
# c2 level=2
# c3 level=2
# a2 level=0
# b1 level=1
# c1 level=2
# c2 level=2
# c3 level=2
# b2 level=1
# c1 level=2
# c2 level=2
# c3 level=2
# b3 level=1
# c1 level=2
# c2 level=2
# c3 level=2
# a3 level=0
# b1 level=1
# c1 level=2
# c2 level=2
# c3 level=2
# b2 level=1
# c1 level=2
# c2 level=2
# c3 level=2
# b3 level=1
# c1 level=2
# c2 level=2
# c3 level=2
